# %% [markdown]
# <a href="https://colab.research.google.com/github/manda2712/Quiz-F55122034_Andi-Amanda-Andi-Tallagu/blob/main/F55122034_Andi_Amanda_A_T.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import cv2

# Menggunakan PIL
image_pil = Image.open('/content/citraplat.jpeg')
image_pil.show()

# Menggunakan OpenCV
image_cv = cv2.imread('/content/citraplat.jpeg')
image_cv_rgb = cv2.cvtColor(image_cv, cv2.COLOR_BGR2RGB)
plt.imshow(image_cv_rgb)
plt.axis('off')
plt.show()

# %%
from PIL import Image
import cv2
import matplotlib.pyplot as plt

# Menggunakan PIL
image_pil = Image.open('/content/citraplat.jpeg')
image_pil.show()

# Menggunakan OpenCV
image_cv = cv2.imread('/content/citraplat.jpeg')
image_cv_rgb = cv2.cvtColor(image_cv, cv2.COLOR_BGR2RGB)
plt.imshow(image_cv_rgb)
plt.axis('off')
plt.show()

# Konversi gambar ke grayscale
image_gray = cv2.cvtColor(image_cv, cv2.COLOR_BGR2GRAY)

# 1. Deteksi Tepi Menggunakan Filter Sobel:

# Deteksi tepi menggunakan filter Sobel
sobelx = cv2.Sobel(image_gray, cv2.CV_64F, 1, 0, ksize=3)
sobely = cv2.Sobel(image_gray, cv2.CV_64F, 0, 1, ksize=3)

# Kombinasikan hasil Sobel untuk mendapatkan gambar tepi
sobel_combined = cv2.addWeighted(cv2.convertScaleAbs(sobelx), 0.5, cv2.convertScaleAbs(sobely), 0.5, 0)

# Tampilkan gambar hasil deteksi tepi Sobel menggunakan OpenCV
plt.imshow(sobel_combined, cmap='gray')
plt.axis('off')
plt.title('Sobel Edge Detection')
plt.show()

# 2. Deteksi Tepi Menggunakan Metode Canny:

# Deteksi tepi menggunakan metode Canny
canny_edges = cv2.Canny(image_gray, 100, 200)

# Tampilkan gambar hasil deteksi tepi Canny menggunakan OpenCV
plt.imshow(canny_edges, cmap='gray')
plt.axis('off')
plt.title('Canny Edge Detection')
plt.show()

# %%
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Menggunakan PIL
image_pil = Image.open('/content/citraplat.jpeg')
image_pil.show()

# Menggunakan OpenCV
image_cv = cv2.imread('/content/citraplat.jpeg')
image_cv_rgb = cv2.cvtColor(image_cv, cv2.COLOR_BGR2RGB)
plt.imshow(image_cv_rgb)
plt.axis('off')
plt.title('Original Image')
plt.show()

# Konversi gambar ke grayscale
image_gray = cv2.cvtColor(image_cv, cv2.COLOR_BGR2GRAY)

# 1. Deteksi Tepi Menggunakan Filter Sobel:

# Deteksi tepi menggunakan filter Sobel
sobelx = cv2.Sobel(image_gray, cv2.CV_64F, 1, 0, ksize=3)
sobely = cv2.Sobel(image_gray, cv2.CV_64F, 0, 1, ksize=3)

# Kombinasikan hasil Sobel untuk mendapatkan gambar tepi
sobel_combined = cv2.addWeighted(cv2.convertScaleAbs(sobelx), 0.5, cv2.convertScaleAbs(sobely), 0.5, 0)


# 4. Cropping Random:

# Mengambil ukuran gambar
height, width, _ = image_cv.shape

# Titik awal cropping
start_row = np.random.randint(0, height - 100)
start_col = np.random.randint(0, width - 100)

# Titik akhir cropping
end_row = start_row + 100
end_col = start_col + 100

# Melakukan cropping
cropped_image = image_cv_rgb[start_row:end_row, start_col:end_col]

plt.imshow(cropped_image)
plt.axis('off')
plt.title('Random Cropped Image')
plt.show()

# 5. Half-size Center Cropping:

# Titik awal cropping
start_row = int(height * 0.25)
start_col = int(width * 0.25)

# Titik akhir cropping
end_row = int(height * 0.75)
end_col = int(width * 0.75)

# Melakukan cropping
half_cropped_image = image_cv_rgb[start_row:end_row, start_col:end_col]

plt.imshow(half_cropped_image)
plt.axis('off')
plt.title('Half-size Center Cropped Image')
plt.show()

# %%
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Menggunakan PIL
image_pil = Image.open('/content/citraplat.jpeg')
image_pil.show()

# Menggunakan OpenCV
image_cv = cv2.imread('/content/citraplat.jpeg')
image_cv_rgb = cv2.cvtColor(image_cv, cv2.COLOR_BGR2RGB)
plt.imshow(image_cv_rgb)
plt.axis('off')
plt.title('Original Image')
plt.show()

# Konversi gambar ke grayscale
image_gray = cv2.cvtColor(image_cv, cv2.COLOR_BGR2GRAY)


#  Transformasi Gambar (Putih menjadi Hitam, Hitam menjadi Putih):

transformed_image = cv2.bitwise_not(image_gray)

plt.imshow(transformed_image, cmap='gray')
plt.axis('off')
plt.title('Transformed Image')
plt.show()

transformed_image_inverse = cv2.bitwise_not(transformed_image)

plt.imshow(transformed_image_inverse, cmap='gray')
plt.axis('off')
plt.title('Inverse Transformed Image')
plt.show()

# %%
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Menggunakan PIL
image_pil = Image.open('/content/citraplat.jpeg')
image_pil.show()

# Menggunakan OpenCV
image_cv = cv2.imread('/content/citraplat.jpeg')
image_cv_rgb = cv2.cvtColor(image_cv, cv2.COLOR_BGR2RGB)
plt.imshow(image_cv_rgb)
plt.axis('off')
plt.title('Original Image')
plt.show()


# Tambahkan Salt and Pepper Noise pada gambar grayscale:
salt_pepper_noise = np.zeros(image_gray.shape, np.uint8)
cv2.randu(salt_pepper_noise, 0, 255)

black_pixels = salt_pepper_noise < 30
white_pixels = salt_pepper_noise > 225

image_salt_pepper = image_gray.copy()
image_salt_pepper[black_pixels] = 0
image_salt_pepper[white_pixels] = 255

plt.imshow(image_salt_pepper, cmap='gray')
plt.axis('off')
plt.title('Salt and Pepper Noise')
plt.show()

# Tambahkan Gaussian Noise:
mean = 0
var = 0.1
sigma = var ** 0.5
gaussian = np.random.normal(mean, sigma, image_gray.shape)
gaussian = gaussian.reshape(image_gray.shape).astype('uint8')

image_gaussian = cv2.add(image_gray, gaussian)

plt.imshow(image_gaussian, cmap='gray')
plt.axis('off')
plt.title('Gaussian Noise')
plt.show()

# %%
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Menggunakan PIL
image_pil = Image.open('/content/citraplat.jpeg')
image_pil.show()

# Menggunakan OpenCV
image_cv = cv2.imread('/content/citraplat.jpeg')
image_cv_rgb = cv2.cvtColor(image_cv, cv2.COLOR_BGR2RGB)
plt.imshow(image_cv_rgb)
plt.axis('off')
plt.title('Original Image')
plt.show()


# Transformasi Geometri: Rotasi
rows, cols = image_gray.shape
M = cv2.getRotationMatrix2D((cols/2, rows/2), 45, 1)  # Rotasi 45 derajat
rotated_image = cv2.warpAffine(image_gray, M, (cols, rows))

plt.imshow(rotated_image, cmap='gray')
plt.axis('off')
plt.title('Rotated Image')
plt.show()

# Transformasi Geometri: Flip Vertikal
flipped_vertical = cv2.flip(image_gray, 0)

plt.imshow(flipped_vertical, cmap='gray')
plt.axis('off')
plt.title('Flipped Vertical Image')
plt.show()

# Transformasi Geometri: Flip Horizontal
flipped_horizontal = cv2.flip(image_gray, 1)

plt.imshow(flipped_horizontal, cmap='gray')
plt.axis('off')
plt.title('Flipped Horizontal Image')
plt.show()
